# %% [markdown]
# ## Pandas is an open source library for data manipulation and analysis in python.
#
# - Helps to peform EDA on large data .Has inbuilt functions for analyzing, cleaning, exploring, and manipulating data
# - Has 2 datatypes
# - Series
#     - A Pandas Series is like a column in a table.
#     - It is a one-dimensional array holding data of any type.
#
# - Data Frame
#     - Data sets in Pandas are usually multi-dimensional tables, called DataFrames.
#     - Series is like a column, a DataFrame is the whole table
#
#
# Python Odyssey :
# https://youtu.be/g_r_mjACRyc?list=PLUgYBRHnEddOP6jiL0pI0mw6qRIyWp8tS
#
# Python Odyssey repo:
# https://github.com/AjitAntony

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('g_r_mjACRyc')

# %% [markdown]
# # Creating a Series

# %%
import pandas as pd

weekdays=["mon","tue","wed"]
weekdays=pd.Series(weekdays)
weekdays
# Out:
# 0    mon
# 1    tue
# 2    wed
# dtype: object

# %%
type(weekdays)
# Out:
# pandas.core.series.Series

# %%
weekdays.size
# Out:
# 3

# %%
weekdays[2]
# Out:
# 'wed'

# %% [markdown]
# # Accessing data in a Series

# %%
weekdays[0:3]
# Out:
# 0    mon
# 1    tue
# 2    wed
# dtype: object

# %% [markdown]
# # DataFrame

# %% [markdown]
# # Loading the dataset and library

# %%
# csv : "indian-movie-theatres.csv"
theater=pd.read_csv("indian-movie-theatres.csv")
type(theater)
# Out:
# pandas.core.frame.DataFrame

# %%
 theater
# Out:
#           city                                    theatre_name  \
# 0    Ahmedabad  AB Miniplex: Shivranjini Cross Road, Satellite
# 1    Ahmedabad                         Amber Cinema: Ahmedabad
# 2    Ahmedabad                        Anupam Cinema: Ahmedabad
# 3    Ahmedabad                       Apsara Cinema, Behrampura
# 4    Ahmedabad                     Aradhana Cinema, Behrampura
# ..         ...                                             ...
# 573     Mumbai                         Silver Cinema, Ambewadi
# 574     Mumbai                         Sterling Cineplex: Fort
# 575     Mumbai                            Sun City: Vile Parle
# 576     Mumbai                      Super Cinema, Bharat Nagar
# 577     Mumbai                        Super Cinema: Grant Road
#
#      average_ticket_price  total_seats  no_screens           type  \
# 0              125.619048          302           3      Multiplex
# 1              100.833333          763           1  Single Screen
# 2              125.833333          781           1  Single Screen
# 3                     NaN         1117           1  Single Screen
# 4                     NaN          455           1  Single Screen
# ..                    ...          ...         ...            ...
# 573                   NaN          636           1  Single Screen
# 574            167.541667          900           3      Multiplex
# 575            180.208333          615           2      Multiplex
# 576                   NaN          822           1  Single Screen
# 577                   NaN          822           1  Single Screen
#
#     theatre_chain
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 573           NaN
# 574           NaN
# 575           NaN
# 576           NaN
# 577           NaN
#
# [578 rows x 7 columns]

# %% [markdown]
# # View first 5 records

# %%
 theater.head()
# Out:
#         city                                    theatre_name  \
# 0  Ahmedabad  AB Miniplex: Shivranjini Cross Road, Satellite
# 1  Ahmedabad                         Amber Cinema: Ahmedabad
# 2  Ahmedabad                        Anupam Cinema: Ahmedabad
# 3  Ahmedabad                       Apsara Cinema, Behrampura
# 4  Ahmedabad                     Aradhana Cinema, Behrampura
#
#    average_ticket_price  total_seats  no_screens           type theatre_chain
# 0            125.619048          302           3      Multiplex           NaN
# 1            100.833333          763           1  Single Screen           NaN
# 2            125.833333          781           1  Single Screen           NaN
# 3                   NaN         1117           1  Single Screen           NaN
# 4                   NaN          455           1  Single Screen           NaN

# %% [markdown]
# # View last  5 records

# %%
 theater.tail()
# Out:
#        city                theatre_name  average_ticket_price  total_seats  \
# 573  Mumbai     Silver Cinema, Ambewadi                   NaN          636
# 574  Mumbai     Sterling Cineplex: Fort            167.541667          900
# 575  Mumbai        Sun City: Vile Parle            180.208333          615
# 576  Mumbai  Super Cinema, Bharat Nagar                   NaN          822
# 577  Mumbai    Super Cinema: Grant Road                   NaN          822
#
#      no_screens           type theatre_chain
# 573           1  Single Screen           NaN
# 574           3      Multiplex           NaN
# 575           2      Multiplex           NaN
# 576           1  Single Screen           NaN
# 577           1  Single Screen           NaN

# %% [markdown]
# # Get Total rows and columns

# %%
 theater.shape
# Out:
# (578, 7)

# %% [markdown]
# # Get total  elements

# %%
 theater.size
# Out:
# 4046

# %% [markdown]
# # Get dataset columns details

# %%
 theater.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578 entries, 0 to 577
# Data columns (total 7 columns):
# city                    578 non-null object
# theatre_name            578 non-null object
# average_ticket_price    402 non-null float64
# total_seats             578 non-null int64
# no_screens              578 non-null int64
# type                    578 non-null object
# theatre_chain           185 non-null object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 31.7+ KB

# %% [markdown]
# # Retrieve  : Select rows 1-10

# %%
theater.iloc[1:10]
# Out:
#         city                          theatre_name  average_ticket_price  \
# 1  Ahmedabad               Amber Cinema: Ahmedabad            100.833333
# 2  Ahmedabad              Anupam Cinema: Ahmedabad            125.833333
# 3  Ahmedabad             Apsara Cinema, Behrampura                   NaN
# 4  Ahmedabad           Aradhana Cinema, Behrampura                   NaN
# 5  Ahmedabad               Carnival: Himalaya Mall            189.050926
# 6  Ahmedabad           Cinemax: Dev Arc, Ahmedabad            176.435185
# 7  Ahmedabad        Cinemax: Red Carpet, Ahmedabad            152.052469
# 8  Ahmedabad              Cinemax: Shiv, Ahmedabad            176.277778
# 9  Ahmedabad  Cinepolis: Alpha One Mall, Ahmedabad            197.949495
#
#    total_seats  no_screens           type theatre_chain
# 1          763           1  Single Screen           NaN
# 2          781           1  Single Screen           NaN
# 3         1117           1  Single Screen           NaN
# 4          455           1  Single Screen           NaN
# 5         1110           5      Multiplex      Carnival
# 6         1047           4      Multiplex           PVR
# 7          991           4      Multiplex           PVR
# 8          637           3      Multiplex           PVR
# 9         1136           6      Multiplex     Cinepolis

# %% [markdown]
# # Retrieve : Select columns in specific postion

# %%
theater.iloc[:,[2,3,4]]
# Out:
#      average_ticket_price  total_seats  no_screens
# 0              125.619048          302           3
# 1              100.833333          763           1
# 2              125.833333          781           1
# 3                     NaN         1117           1
# 4                     NaN          455           1
# ..                    ...          ...         ...
# 573                   NaN          636           1
# 574            167.541667          900           3
# 575            180.208333          615           2
# 576                   NaN          822           1
# 577                   NaN          822           1
#
# [578 rows x 3 columns]

# %% [markdown]
# # Retrieve : Select  columns with specifc lables

# %%
theater[["average_ticket_price","total_seats","no_screens"]]
# Out:
#      average_ticket_price  total_seats  no_screens
# 0              125.619048          302           3
# 1              100.833333          763           1
# 2              125.833333          781           1
# 3                     NaN         1117           1
# 4                     NaN          455           1
# ..                    ...          ...         ...
# 573                   NaN          636           1
# 574            167.541667          900           3
# 575            180.208333          615           2
# 576                   NaN          822           1
# 577                   NaN          822           1
#
# [578 rows x 3 columns]

# %% [markdown]
# # Retrieve : Select columns between  theatre_name : type

# %%
theater.loc[:,"theatre_name":"type"]
# Out:
#                                        theatre_name  average_ticket_price  \
# 0    AB Miniplex: Shivranjini Cross Road, Satellite            125.619048
# 1                           Amber Cinema: Ahmedabad            100.833333
# 2                          Anupam Cinema: Ahmedabad            125.833333
# 3                         Apsara Cinema, Behrampura                   NaN
# 4                       Aradhana Cinema, Behrampura                   NaN
# ..                                              ...                   ...
# 573                         Silver Cinema, Ambewadi                   NaN
# 574                         Sterling Cineplex: Fort            167.541667
# 575                            Sun City: Vile Parle            180.208333
# 576                      Super Cinema, Bharat Nagar                   NaN
# 577                        Super Cinema: Grant Road                   NaN
#
#      total_seats  no_screens           type
# 0            302           3      Multiplex
# 1            763           1  Single Screen
# 2            781           1  Single Screen
# 3           1117           1  Single Screen
# 4            455           1  Single Screen
# ..           ...         ...            ...
# 573          636           1  Single Screen
# 574          900           3      Multiplex
# 575          615           2      Multiplex
# 576          822           1  Single Screen
# 577          822           1  Single Screen
#
# [578 rows x 5 columns]

# %% [markdown]
# # Retrieve : Select columns between theatre_name : type for rows between 2-4

# %%
theater.loc[2:4,"theatre_name":"type"]
# Out:
#                   theatre_name  average_ticket_price  total_seats  no_screens  \
# 2     Anupam Cinema: Ahmedabad            125.833333          781           1
# 3    Apsara Cinema, Behrampura                   NaN         1117           1
# 4  Aradhana Cinema, Behrampura                   NaN          455           1
#
#             type
# 2  Single Screen
# 3  Single Screen
# 4  Single Screen

# %% [markdown]
# # Retrieve : single value by index

# %%
theater.iat[1,1]
# Out:
# 'Amber Cinema: Ahmedabad'

# %% [markdown]
# # Retrieve  single value by label

# %%
theater.at[4,"total_seats"]
# Out:
# 455

# %% [markdown]
# # get all column names

# %%
theater.columns
# Out:
# Index(['city', 'theatre_name', 'average_ticket_price', 'total_seats',
#        'no_screens', 'type', 'theatre_chain'],
#       dtype='object')

# %% [markdown]
# # Rename a column

# %%
theater.rename(columns={"theatre_chain":"talkies_names"},inplace=True)
#theater=theater.rename(columns={"theatre_chain":"talkies_names"})

# %%
theater.columns
# Out:
# Index(['city', 'theatre_name', 'average_ticket_price', 'total_seats',
#        'no_screens', 'type', 'talkies_names'],
#       dtype='object')

# %%
theater.iloc[1:10]
# Out:
#         city                          theatre_name  average_ticket_price  \
# 1  Ahmedabad               Amber Cinema: Ahmedabad            100.833333
# 2  Ahmedabad              Anupam Cinema: Ahmedabad            125.833333
# 3  Ahmedabad             Apsara Cinema, Behrampura                   NaN
# 4  Ahmedabad           Aradhana Cinema, Behrampura                   NaN
# 5  Ahmedabad               Carnival: Himalaya Mall            189.050926
# 6  Ahmedabad           Cinemax: Dev Arc, Ahmedabad            176.435185
# 7  Ahmedabad        Cinemax: Red Carpet, Ahmedabad            152.052469
# 8  Ahmedabad              Cinemax: Shiv, Ahmedabad            176.277778
# 9  Ahmedabad  Cinepolis: Alpha One Mall, Ahmedabad            197.949495
#
#    total_seats  no_screens           type talkies_names
# 1          763           1  Single Screen           NaN
# 2          781           1  Single Screen           NaN
# 3         1117           1  Single Screen           NaN
# 4          455           1  Single Screen           NaN
# 5         1110           5      Multiplex      Carnival
# 6         1047           4      Multiplex           PVR
# 7          991           4      Multiplex           PVR
# 8          637           3      Multiplex           PVR
# 9         1136           6      Multiplex     Cinepolis

# %% [markdown]
# # Add a columns

# %%
country_series=pd.Series(["India"]*len(theater))
country_series
# Out:
# 0      India
# 1      India
# 2      India
# 3      India
# 4      India
#        ...
# 573    India
# 574    India
# 575    India
# 576    India
# 577    India
# Length: 578, dtype: object

# %%
theater=pd.concat([theater,country_series],axis=1)

# %%
theater.columns
# Out:
# Index([                'city',         'theatre_name', 'average_ticket_price',
#                 'total_seats',           'no_screens',                 'type',
#               'talkies_names',                      0],
#       dtype='object')

# %%
theater.rename(columns={0:"Country"},inplace=True)

# %%
theater.columns
# Out:
# Index(['city', 'theatre_name', 'average_ticket_price', 'total_seats',
#        'no_screens', 'type', 'talkies_names', 'Country'],
#       dtype='object')

# %%
theater
# Out:
#           city                                    theatre_name  \
# 0    Ahmedabad  AB Miniplex: Shivranjini Cross Road, Satellite
# 1    Ahmedabad                         Amber Cinema: Ahmedabad
# 2    Ahmedabad                        Anupam Cinema: Ahmedabad
# 3    Ahmedabad                       Apsara Cinema, Behrampura
# 4    Ahmedabad                     Aradhana Cinema, Behrampura
# ..         ...                                             ...
# 573     Mumbai                         Silver Cinema, Ambewadi
# 574     Mumbai                         Sterling Cineplex: Fort
# 575     Mumbai                            Sun City: Vile Parle
# 576     Mumbai                      Super Cinema, Bharat Nagar
# 577     Mumbai                        Super Cinema: Grant Road
#
#      average_ticket_price  total_seats  no_screens           type  \
# 0              125.619048          302           3      Multiplex
# 1              100.833333          763           1  Single Screen
# 2              125.833333          781           1  Single Screen
# 3                     NaN         1117           1  Single Screen
# 4                     NaN          455           1  Single Screen
# ..                    ...          ...         ...            ...
# 573                   NaN          636           1  Single Screen
# 574            167.541667          900           3      Multiplex
# 575            180.208333          615           2      Multiplex
# 576                   NaN          822           1  Single Screen
# 577                   NaN          822           1  Single Screen
#
#     talkies_names Country
# 0             NaN   India
# 1             NaN   India
# 2             NaN   India
# 3             NaN   India
# 4             NaN   India
# ..            ...     ...
# 573           NaN   India
# 574           NaN   India
# 575           NaN   India
# 576           NaN   India
# 577           NaN   India
#
# [578 rows x 8 columns]

# %% [markdown]
# # Filtering : Using Logical operators =,<,>

# %% [markdown]
# # Filtering theaters in chennai alone

# %%
theater[theater["city"]=="Chennai"]
# Out:
#         city                                       theatre_name  \
# 179  Chennai                           Abirami Cinemas: Chennai
# 180  Chennai                                Agasthiya, T.H Road
# 181  Chennai                              AGS Cinemas: T. Nagar
# 182  Chennai                           AGS Cinemas: Villivakkam
# 183  Chennai                                     Albert Complex
# 184  Chennai                              Anna Theatre: Chennai
# 185  Chennai                      Annai Karumari, Virugambakkam
# 186  Chennai                             Arvind Theatre A/C dts
# 187  Chennai                              AVM Rajeswari A/C dts
# 188  Chennai                 Baby Albert Theatre, Whannels Road
# 189  Chennai                            Bala Theatre, Anna Road
# 190  Chennai             Bharath Theatre Dolby AtmosDolby Atmos
# 191  Chennai                            Casino Theatre: Chennai
# 192  Chennai                       Chandran Theatre, Ashoknagar
# 193  Chennai                                  Devi Karumari A/C
# 194  Chennai                                       Devicineplex
# 195  Chennai                                         Ega Cinema
# 196  Chennai                     Ganapathy Ram Theatre: Chennai
# 197  Chennai                   GK Cinemas 2K Dolby Atmos: Porur
# 198  Chennai                          INOX National: Arcot Road
# 199  Chennai            INOX: Chennai Citi Centre, Dr. RK Salai
# 200  Chennai          Jothi Theatre 4K A/c DTS: ST Thomas Mount
# 201  Chennai                                 Kamala CinemasF&B;
# 202  Chennai                                 Kasi4K Dolby Atmos
# 203  Chennai                      Krishnaveni, South Usman Raod
# 204  Chennai           Kumaran Theatre QUBE A/C DTS: Madipakkam
# 205  Chennai                              Luxe Cinemas: Chennai
# 206  Chennai                 Mahalakshmi Talkies, Strahans Road
# 207  Chennai                            Maharani Theatre 2K dts
# 208  Chennai                              Mayura, Arakonam Road
# 209  Chennai                                         MM Theatre
# 210  Chennai              Murugan Cinemas - AmbatturDolby Atmos
# 211  Chennai                                   Nadhamuni Cinema
# 212  Chennai                      Padmam, Poonamallee High Road
# 213  Chennai                                Pandian, Moolakadai
# 214  Chennai                                 PVR: Ampa, Chennai
# 215  Chennai                            PVR: Velachery, Chennai
# 216  Chennai                     Raj Theatre - A/C DTS: Chennai
# 217  Chennai                           Rakki Cinemas - Ambattur
# 218  Chennai                     Rohini Silver Screens: Chennai
# 219  Chennai                      Roopam, Poonamallee High Road
# 220  Chennai                                     Sangam Cinemas
# 221  Chennai                  Saravana Theatre, Brick Kiln Road
# 222  Chennai                  Sathyam Royapettah, Lloyds Estate
# 223  Chennai              SK-Marlen Cinemas 2K, Guindy: Alandur
# 224  Chennai                      Spectrum Mall, Perambur North
# 225  Chennai                  Sri Bhuvaneshwari Theatre A/C dts
# 226  Chennai  Sri Ganga Cinemas Dolby Atmos - KolathurDolby ...
# 227  Chennai                              Sri Murugan, Ambattur
# 228  Chennai                                  Srinivasa Theatre
# 229  Chennai                  The Forum Vijaya Mall, Vadapalani
# 230  Chennai                             Thirumurugan, Ambattur
# 231  Chennai                                    Udhayam Complex
# 232  Chennai                        Udhayam Theatre, Ashoknagar
# 233  Chennai                 Vetrrivel Theatre 2K - Nanganallur
# 234  Chennai                         Woodlands Complex: Chennai
#
#      average_ticket_price  total_seats  no_screens           type  \
# 179            113.583333         1656           4      Multiplex
# 180                   NaN         1004           1  Single Screen
# 181             82.700000          884           4      Multiplex
# 182             82.700000         1473           5      Multiplex
# 183                   NaN         1200           1  Single Screen
# 184             94.600000          364           1  Single Screen
# 185                   NaN          196           1  Single Screen
# 186                   NaN          445           1  Single Screen
# 187                   NaN          603           1  Single Screen
# 188                   NaN          242           1  Single Screen
# 189                   NaN          518           1  Single Screen
# 190                   NaN          963           1  Single Screen
# 191             59.000000           83           1  Single Screen
# 192                   NaN          515           1  Single Screen
# 193                   NaN          850           1  Single Screen
# 194                   NaN         2462           1  Single Screen
# 195                   NaN         1168           2      Multiplex
# 196             90.000000          852           1  Single Screen
# 197            116.190000          557           2      Multiplex
# 198            153.600000         1182           5      Multiplex
# 199            153.600000          528           4      Multiplex
# 200              0.000000          805           1  Single Screen
# 201                   NaN          586           1  Single Screen
# 202                   NaN          733           1  Single Screen
# 203                   NaN          898           1  Single Screen
# 204              0.000000         1008           1  Single Screen
# 205            153.600000         1844           9      Multiplex
# 206                   NaN         1040           1  Single Screen
# 207                   NaN          910           1  Single Screen
# 208                   NaN          474           1  Single Screen
# 209                   NaN          772           1  Single Screen
# 210                   NaN          960           1  Single Screen
# 211                   NaN          650           1  Single Screen
# 212                   NaN          420           1  Single Screen
# 213                   NaN         1002           1  Single Screen
# 214             82.700000         1794           7      Multiplex
# 215             82.700000         1275           5      Multiplex
# 216            175.000000          950           1  Single Screen
# 217                   NaN          361           1  Single Screen
# 218            104.030000         3175           7      Multiplex
# 219                   NaN          288           1  Single Screen
# 220                   NaN         1662           3      Multiplex
# 221                   NaN          600           1  Single Screen
# 222                   NaN         2283           6      Multiplex
# 223            150.000000          229           1  Single Screen
# 224                   NaN         1395           5      Multiplex
# 225                   NaN          565           1  Single Screen
# 226                   NaN          772           1  Single Screen
# 227                   NaN          960           1  Single Screen
# 228                   NaN          900           1  Single Screen
# 229                   NaN         3010           9      Multiplex
# 230                   NaN          510           1  Single Screen
# 231                   NaN          759           1  Single Screen
# 232                   NaN          759           1  Single Screen
# 233                   NaN          600           1  Single Screen
# 234             69.500000         1713           2      Multiplex
#
#     talkies_names Country
# 179           NaN   India
# 180           NaN   India
# 181   AGS Cinemas   India
# 182   AGS Cinemas   India
# 183           NaN   India
# 184           NaN   India
# 185           NaN   India
# 186           NaN   India
# 187           NaN   India
# 188           NaN   India
# 189           NaN   India
# 190           NaN   India
# 191           NaN   India
# 192           NaN   India
# 193           NaN   India
# 194           NaN   India
# 195           NaN   India
# 196           NaN   India
# 197           NaN   India
# 198          Inox   India
# 199          Inox   India
# 200           NaN   India
# 201           NaN   India
# 202           NaN   India
# 203           NaN   India
# 204           NaN   India
# 205           NaN   India
# 206           NaN   India
# 207           NaN   India
# 208           NaN   India
# 209           NaN   India
# 210           NaN   India
# 211           NaN   India
# 212           NaN   India
# 213           NaN   India
# 214           PVR   India
# 215           PVR   India
# 216           NaN   India
# 217           NaN   India
# 218           NaN   India
# 219           NaN   India
# 220           NaN   India
# 221           NaN   India
# 222   SPI Cinemas   India
# 223           NaN   India
# 224           NaN   India
# 225           NaN   India
# 226           NaN   India
# 227           NaN   India
# 228           NaN   India
# 229   SPI Cinemas   India
# 230           NaN   India
# 231           NaN   India
# 232           NaN   India
# 233           NaN   India
# 234           NaN   India

# %% [markdown]
# # Filtering theaters with seats lesss than 100

# %%
 theater[theater["total_seats"]<100]
# Out:
#           city                                     theatre_name  \
# 36   Bangalore                 7D Mastii: Element Mall, Nagwara
# 37   Bangalore         7D Mastiii: Forum Value Mall, Whitefield
# 38   Bangalore               7D Voyage: Central Mall, Bellandur
# 39   Bangalore                        7D VR Voyage: Garuda Mall
# 87   Bangalore  Maheshwari Digital 4K Cinema: Bannerghatta Road
# 109  Bangalore                       PVR: Forum Gold, Bengaluru
# 120  Bangalore                          PVR: VR Gold, Bengaluru
# 191    Chennai                          Casino Theatre: Chennai
# 235      Delhi      7D Mastiii: TDI Mall, Rajouri Garden, Delhi
# 273      Delhi              PVR: Select City Walk (Gold), Delhi
# 287  Hyderabad                        Amba Theatre: Mehdipatnam
# 321  Hyderabad                    Kalyani Movie Max: Bowenpally
# 323  Hyderabad                         Kumar Theatre: Kachiguda
# 386  Hyderabad                        SSV Cine Park: Patancheru
# 419      Kochi                 Padma Cinema Screen 2: Ernakulam
# 424    Kolkata                    11D Adventureplex: Quest Mall
# 425    Kolkata              7D Adventure Plex: Mani Square Mall
# 549     Mumbai                         PVR ICON: Versova (Gold)
#
#      average_ticket_price  total_seats  no_screens           type  \
# 36             150.000000           18           1  Single Screen
# 37             150.000000           16           1  Single Screen
# 38             180.000000            8           1  Single Screen
# 39             190.000000            8           1  Single Screen
# 87                    NaN            0           0      Multiplex
# 109            825.000000           32           1  Single Screen
# 120            697.025000            1           4      Multiplex
# 191             59.000000           83           1  Single Screen
# 235            170.000000           18           1  Single Screen
# 273            943.750000           40           1  Single Screen
# 287            100.000000           64           1  Single Screen
# 321             70.000000           84           1  Single Screen
# 323             90.000000           74           1  Single Screen
# 386                   NaN            0           0      Multiplex
# 419            110.000000           98           1  Single Screen
# 424            250.000000           30           1  Single Screen
# 425            200.000000           32           1  Single Screen
# 549            616.666667           86           2      Multiplex
#
#     talkies_names Country
# 36     Mastiii 7D   India
# 37     Mastiii 7D   India
# 38      7D Voyage   India
# 39      7D Voyage   India
# 87            NaN   India
# 109           PVR   India
# 120           PVR   India
# 191           NaN   India
# 235           NaN   India
# 273           PVR   India
# 287           NaN   India
# 321           NaN   India
# 323           NaN   India
# 386           NaN   India
# 419           NaN   India
# 424           NaN   India
# 425           NaN   India
# 549           PVR   India

# %% [markdown]
# # Filtering theaters with average_ticket_price  >1000

# %%
 theater[theater["average_ticket_price"]>1000]
# Out:
#       city                         theatre_name  average_ticket_price  \
# 265  Delhi  PVR: Director's Cut, Ambience Delhi           1458.333333
#
#      total_seats  no_screens       type talkies_names Country
# 265          282           4  Multiplex           PVR   India

# %% [markdown]
# # Grouping

# %%
 theater.groupby(['type']).sum()
# Out:
#                average_ticket_price  total_seats  no_screens
# type
# Multiplex              37736.652568       192764         801
# Single Screen          30113.707407       278433         391

# %% [markdown]
# # Grouping and Sorting

# %%
theater.groupby(['type']).sum().sort_values(by="total_seats",ascending=False)
# Out:
#                average_ticket_price  total_seats  no_screens
# type
# Single Screen          30113.707407       278433         391
# Multiplex              37736.652568       192764         801

# %% [markdown]
# # Create a new dataframe from existing dataframe

# %%
chennai=theater[theater["city"]=="Chennai"]
type(chennai)
# Out:
# pandas.core.frame.DataFrame

# %%
chennai
# Out:
#         city                                       theatre_name  \
# 179  Chennai                           Abirami Cinemas: Chennai
# 180  Chennai                                Agasthiya, T.H Road
# 181  Chennai                              AGS Cinemas: T. Nagar
# 182  Chennai                           AGS Cinemas: Villivakkam
# 183  Chennai                                     Albert Complex
# 184  Chennai                              Anna Theatre: Chennai
# 185  Chennai                      Annai Karumari, Virugambakkam
# 186  Chennai                             Arvind Theatre A/C dts
# 187  Chennai                              AVM Rajeswari A/C dts
# 188  Chennai                 Baby Albert Theatre, Whannels Road
# 189  Chennai                            Bala Theatre, Anna Road
# 190  Chennai             Bharath Theatre Dolby AtmosDolby Atmos
# 191  Chennai                            Casino Theatre: Chennai
# 192  Chennai                       Chandran Theatre, Ashoknagar
# 193  Chennai                                  Devi Karumari A/C
# 194  Chennai                                       Devicineplex
# 195  Chennai                                         Ega Cinema
# 196  Chennai                     Ganapathy Ram Theatre: Chennai
# 197  Chennai                   GK Cinemas 2K Dolby Atmos: Porur
# 198  Chennai                          INOX National: Arcot Road
# 199  Chennai            INOX: Chennai Citi Centre, Dr. RK Salai
# 200  Chennai          Jothi Theatre 4K A/c DTS: ST Thomas Mount
# 201  Chennai                                 Kamala CinemasF&B;
# 202  Chennai                                 Kasi4K Dolby Atmos
# 203  Chennai                      Krishnaveni, South Usman Raod
# 204  Chennai           Kumaran Theatre QUBE A/C DTS: Madipakkam
# 205  Chennai                              Luxe Cinemas: Chennai
# 206  Chennai                 Mahalakshmi Talkies, Strahans Road
# 207  Chennai                            Maharani Theatre 2K dts
# 208  Chennai                              Mayura, Arakonam Road
# 209  Chennai                                         MM Theatre
# 210  Chennai              Murugan Cinemas - AmbatturDolby Atmos
# 211  Chennai                                   Nadhamuni Cinema
# 212  Chennai                      Padmam, Poonamallee High Road
# 213  Chennai                                Pandian, Moolakadai
# 214  Chennai                                 PVR: Ampa, Chennai
# 215  Chennai                            PVR: Velachery, Chennai
# 216  Chennai                     Raj Theatre - A/C DTS: Chennai
# 217  Chennai                           Rakki Cinemas - Ambattur
# 218  Chennai                     Rohini Silver Screens: Chennai
# 219  Chennai                      Roopam, Poonamallee High Road
# 220  Chennai                                     Sangam Cinemas
# 221  Chennai                  Saravana Theatre, Brick Kiln Road
# 222  Chennai                  Sathyam Royapettah, Lloyds Estate
# 223  Chennai              SK-Marlen Cinemas 2K, Guindy: Alandur
# 224  Chennai                      Spectrum Mall, Perambur North
# 225  Chennai                  Sri Bhuvaneshwari Theatre A/C dts
# 226  Chennai  Sri Ganga Cinemas Dolby Atmos - KolathurDolby ...
# 227  Chennai                              Sri Murugan, Ambattur
# 228  Chennai                                  Srinivasa Theatre
# 229  Chennai                  The Forum Vijaya Mall, Vadapalani
# 230  Chennai                             Thirumurugan, Ambattur
# 231  Chennai                                    Udhayam Complex
# 232  Chennai                        Udhayam Theatre, Ashoknagar
# 233  Chennai                 Vetrrivel Theatre 2K - Nanganallur
# 234  Chennai                         Woodlands Complex: Chennai
#
#      average_ticket_price  total_seats  no_screens           type  \
# 179            113.583333         1656           4      Multiplex
# 180                   NaN         1004           1  Single Screen
# 181             82.700000          884           4      Multiplex
# 182             82.700000         1473           5      Multiplex
# 183                   NaN         1200           1  Single Screen
# 184             94.600000          364           1  Single Screen
# 185                   NaN          196           1  Single Screen
# 186                   NaN          445           1  Single Screen
# 187                   NaN          603           1  Single Screen
# 188                   NaN          242           1  Single Screen
# 189                   NaN          518           1  Single Screen
# 190                   NaN          963           1  Single Screen
# 191             59.000000           83           1  Single Screen
# 192                   NaN          515           1  Single Screen
# 193                   NaN          850           1  Single Screen
# 194                   NaN         2462           1  Single Screen
# 195                   NaN         1168           2      Multiplex
# 196             90.000000          852           1  Single Screen
# 197            116.190000          557           2      Multiplex
# 198            153.600000         1182           5      Multiplex
# 199            153.600000          528           4      Multiplex
# 200              0.000000          805           1  Single Screen
# 201                   NaN          586           1  Single Screen
# 202                   NaN          733           1  Single Screen
# 203                   NaN          898           1  Single Screen
# 204              0.000000         1008           1  Single Screen
# 205            153.600000         1844           9      Multiplex
# 206                   NaN         1040           1  Single Screen
# 207                   NaN          910           1  Single Screen
# 208                   NaN          474           1  Single Screen
# 209                   NaN          772           1  Single Screen
# 210                   NaN          960           1  Single Screen
# 211                   NaN          650           1  Single Screen
# 212                   NaN          420           1  Single Screen
# 213                   NaN         1002           1  Single Screen
# 214             82.700000         1794           7      Multiplex
# 215             82.700000         1275           5      Multiplex
# 216            175.000000          950           1  Single Screen
# 217                   NaN          361           1  Single Screen
# 218            104.030000         3175           7      Multiplex
# 219                   NaN          288           1  Single Screen
# 220                   NaN         1662           3      Multiplex
# 221                   NaN          600           1  Single Screen
# 222                   NaN         2283           6      Multiplex
# 223            150.000000          229           1  Single Screen
# 224                   NaN         1395           5      Multiplex
# 225                   NaN          565           1  Single Screen
# 226                   NaN          772           1  Single Screen
# 227                   NaN          960           1  Single Screen
# 228                   NaN          900           1  Single Screen
# 229                   NaN         3010           9      Multiplex
# 230                   NaN          510           1  Single Screen
# 231                   NaN          759           1  Single Screen
# 232                   NaN          759           1  Single Screen
# 233                   NaN          600           1  Single Screen
# 234             69.500000         1713           2      Multiplex
#
#     talkies_names Country
# 179           NaN   India
# 180           NaN   India
# 181   AGS Cinemas   India
# 182   AGS Cinemas   India
# 183           NaN   India
# 184           NaN   India
# 185           NaN   India
# 186           NaN   India
# 187           NaN   India
# 188           NaN   India
# 189           NaN   India
# 190           NaN   India
# 191           NaN   India
# 192           NaN   India
# 193           NaN   India
# 194           NaN   India
# 195           NaN   India
# 196           NaN   India
# 197           NaN   India
# 198          Inox   India
# 199          Inox   India
# 200           NaN   India
# 201           NaN   India
# 202           NaN   India
# 203           NaN   India
# 204           NaN   India
# 205           NaN   India
# 206           NaN   India
# 207           NaN   India
# 208           NaN   India
# 209           NaN   India
# 210           NaN   India
# 211           NaN   India
# 212           NaN   India
# 213           NaN   India
# 214           PVR   India
# 215           PVR   India
# 216           NaN   India
# 217           NaN   India
# 218           NaN   India
# 219           NaN   India
# 220           NaN   India
# 221           NaN   India
# 222   SPI Cinemas   India
# 223           NaN   India
# 224           NaN   India
# 225           NaN   India
# 226           NaN   India
# 227           NaN   India
# 228           NaN   India
# 229   SPI Cinemas   India
# 230           NaN   India
# 231           NaN   India
# 232           NaN   India
# 233           NaN   India
# 234           NaN   India

# %% [markdown]
# # check for missing values

# %%
chennai.isnull().sum()
# Out:
# city                     0
# theatre_name             0
# average_ticket_price    38
# total_seats              0
# no_screens               0
# type                     0
# talkies_names           48
# Country                  0
# dtype: int64

# %% [markdown]
# # Get column names that have nan values

# %%
nan_columns=chennai.isna().any()
nan_columns
# Out:
# city                    False
# theatre_name            False
# average_ticket_price     True
# total_seats             False
# no_screens              False
# type                    False
# talkies_names            True
# Country                 False
# dtype: bool

# %% [markdown]
# # Drop a column

# %%
 theater.drop(["average_ticket_price","talkies_names"],axis=1,inplace=True)

# %%
theater.columns
# Out:
# Index(['city', 'theatre_name', 'total_seats', 'no_screens', 'type', 'Country'], dtype='object')

# %%
theater
# Out:
#           city                                    theatre_name  total_seats  \
# 0    Ahmedabad  AB Miniplex: Shivranjini Cross Road, Satellite          302
# 1    Ahmedabad                         Amber Cinema: Ahmedabad          763
# 2    Ahmedabad                        Anupam Cinema: Ahmedabad          781
# 3    Ahmedabad                       Apsara Cinema, Behrampura         1117
# 4    Ahmedabad                     Aradhana Cinema, Behrampura          455
# ..         ...                                             ...          ...
# 573     Mumbai                         Silver Cinema, Ambewadi          636
# 574     Mumbai                         Sterling Cineplex: Fort          900
# 575     Mumbai                            Sun City: Vile Parle          615
# 576     Mumbai                      Super Cinema, Bharat Nagar          822
# 577     Mumbai                        Super Cinema: Grant Road          822
#
#      no_screens           type Country
# 0             3      Multiplex   India
# 1             1  Single Screen   India
# 2             1  Single Screen   India
# 3             1  Single Screen   India
# 4             1  Single Screen   India
# ..          ...            ...     ...
# 573           1  Single Screen   India
# 574           3      Multiplex   India
# 575           2      Multiplex   India
# 576           1  Single Screen   India
# 577           1  Single Screen   India
#
# [578 rows x 6 columns]

# %% [markdown]
# # Use fillna to repalce NaN values operation

# %%
 chennai["talkies_names"].fillna("Other",inplace=True)

# %%
chennai["type"]=chennai["type"].apply(lambda x:  "Multiscreen" if x == "Multiplex" else x )

# %% [markdown]
# # Use Apply function

# %%
 chennai
# Out:
#         city                                       theatre_name  \
# 179  Chennai                           Abirami Cinemas: Chennai
# 180  Chennai                                Agasthiya, T.H Road
# 181  Chennai                              AGS Cinemas: T. Nagar
# 182  Chennai                           AGS Cinemas: Villivakkam
# 183  Chennai                                     Albert Complex
# 184  Chennai                              Anna Theatre: Chennai
# 185  Chennai                      Annai Karumari, Virugambakkam
# 186  Chennai                             Arvind Theatre A/C dts
# 187  Chennai                              AVM Rajeswari A/C dts
# 188  Chennai                 Baby Albert Theatre, Whannels Road
# 189  Chennai                            Bala Theatre, Anna Road
# 190  Chennai             Bharath Theatre Dolby AtmosDolby Atmos
# 191  Chennai                            Casino Theatre: Chennai
# 192  Chennai                       Chandran Theatre, Ashoknagar
# 193  Chennai                                  Devi Karumari A/C
# 194  Chennai                                       Devicineplex
# 195  Chennai                                         Ega Cinema
# 196  Chennai                     Ganapathy Ram Theatre: Chennai
# 197  Chennai                   GK Cinemas 2K Dolby Atmos: Porur
# 198  Chennai                          INOX National: Arcot Road
# 199  Chennai            INOX: Chennai Citi Centre, Dr. RK Salai
# 200  Chennai          Jothi Theatre 4K A/c DTS: ST Thomas Mount
# 201  Chennai                                 Kamala CinemasF&B;
# 202  Chennai                                 Kasi4K Dolby Atmos
# 203  Chennai                      Krishnaveni, South Usman Raod
# 204  Chennai           Kumaran Theatre QUBE A/C DTS: Madipakkam
# 205  Chennai                              Luxe Cinemas: Chennai
# 206  Chennai                 Mahalakshmi Talkies, Strahans Road
# 207  Chennai                            Maharani Theatre 2K dts
# 208  Chennai                              Mayura, Arakonam Road
# 209  Chennai                                         MM Theatre
# 210  Chennai              Murugan Cinemas - AmbatturDolby Atmos
# 211  Chennai                                   Nadhamuni Cinema
# 212  Chennai                      Padmam, Poonamallee High Road
# 213  Chennai                                Pandian, Moolakadai
# 214  Chennai                                 PVR: Ampa, Chennai
# 215  Chennai                            PVR: Velachery, Chennai
# 216  Chennai                     Raj Theatre - A/C DTS: Chennai
# 217  Chennai                           Rakki Cinemas - Ambattur
# 218  Chennai                     Rohini Silver Screens: Chennai
# 219  Chennai                      Roopam, Poonamallee High Road
# 220  Chennai                                     Sangam Cinemas
# 221  Chennai                  Saravana Theatre, Brick Kiln Road
# 222  Chennai                  Sathyam Royapettah, Lloyds Estate
# 223  Chennai              SK-Marlen Cinemas 2K, Guindy: Alandur
# 224  Chennai                      Spectrum Mall, Perambur North
# 225  Chennai                  Sri Bhuvaneshwari Theatre A/C dts
# 226  Chennai  Sri Ganga Cinemas Dolby Atmos - KolathurDolby ...
# 227  Chennai                              Sri Murugan, Ambattur
# 228  Chennai                                  Srinivasa Theatre
# 229  Chennai                  The Forum Vijaya Mall, Vadapalani
# 230  Chennai                             Thirumurugan, Ambattur
# 231  Chennai                                    Udhayam Complex
# 232  Chennai                        Udhayam Theatre, Ashoknagar
# 233  Chennai                 Vetrrivel Theatre 2K - Nanganallur
# 234  Chennai                         Woodlands Complex: Chennai
#
#      average_ticket_price  total_seats  no_screens           type  \
# 179            113.583333         1656           4    Multiscreen
# 180                   NaN         1004           1  Single Screen
# 181             82.700000          884           4    Multiscreen
# 182             82.700000         1473           5    Multiscreen
# 183                   NaN         1200           1  Single Screen
# 184             94.600000          364           1  Single Screen
# 185                   NaN          196           1  Single Screen
# 186                   NaN          445           1  Single Screen
# 187                   NaN          603           1  Single Screen
# 188                   NaN          242           1  Single Screen
# 189                   NaN          518           1  Single Screen
# 190                   NaN          963           1  Single Screen
# 191             59.000000           83           1  Single Screen
# 192                   NaN          515           1  Single Screen
# 193                   NaN          850           1  Single Screen
# 194                   NaN         2462           1  Single Screen
# 195                   NaN         1168           2    Multiscreen
# 196             90.000000          852           1  Single Screen
# 197            116.190000          557           2    Multiscreen
# 198            153.600000         1182           5    Multiscreen
# 199            153.600000          528           4    Multiscreen
# 200              0.000000          805           1  Single Screen
# 201                   NaN          586           1  Single Screen
# 202                   NaN          733           1  Single Screen
# 203                   NaN          898           1  Single Screen
# 204              0.000000         1008           1  Single Screen
# 205            153.600000         1844           9    Multiscreen
# 206                   NaN         1040           1  Single Screen
# 207                   NaN          910           1  Single Screen
# 208                   NaN          474           1  Single Screen
# 209                   NaN          772           1  Single Screen
# 210                   NaN          960           1  Single Screen
# 211                   NaN          650           1  Single Screen
# 212                   NaN          420           1  Single Screen
# 213                   NaN         1002           1  Single Screen
# 214             82.700000         1794           7    Multiscreen
# 215             82.700000         1275           5    Multiscreen
# 216            175.000000          950           1  Single Screen
# 217                   NaN          361           1  Single Screen
# 218            104.030000         3175           7    Multiscreen
# 219                   NaN          288           1  Single Screen
# 220                   NaN         1662           3    Multiscreen
# 221                   NaN          600           1  Single Screen
# 222                   NaN         2283           6    Multiscreen
# 223            150.000000          229           1  Single Screen
# 224                   NaN         1395           5    Multiscreen
# 225                   NaN          565           1  Single Screen
# 226                   NaN          772           1  Single Screen
# 227                   NaN          960           1  Single Screen
# 228                   NaN          900           1  Single Screen
# 229                   NaN         3010           9    Multiscreen
# 230                   NaN          510           1  Single Screen
# 231                   NaN          759           1  Single Screen
# 232                   NaN          759           1  Single Screen
# 233                   NaN          600           1  Single Screen
# 234             69.500000         1713           2    Multiscreen
#
#     talkies_names Country
# 179         Other   India
# 180         Other   India
# 181   AGS Cinemas   India
# 182   AGS Cinemas   India
# 183         Other   India
# 184         Other   India
# 185         Other   India
# 186         Other   India
# 187         Other   India
# 188         Other   India
# 189         Other   India
# 190         Other   India
# 191         Other   India
# 192         Other   India
# 193         Other   India
# 194         Other   India
# 195         Other   India
# 196         Other   India
# 197         Other   India
# 198          Inox   India
# 199          Inox   India
# 200         Other   India
# 201         Other   India
# 202         Other   India
# 203         Other   India
# 204         Other   India
# 205         Other   India
# 206         Other   India
# 207         Other   India
# 208         Other   India
# 209         Other   India
# 210         Other   India
# 211         Other   India
# 212         Other   India
# 213         Other   India
# 214           PVR   India
# 215           PVR   India
# 216         Other   India
# 217         Other   India
# 218         Other   India
# 219         Other   India
# 220         Other   India
# 221         Other   India
# 222   SPI Cinemas   India
# 223         Other   India
# 224         Other   India
# 225         Other   India
# 226         Other   India
# 227         Other   India
# 228         Other   India
# 229   SPI Cinemas   India
# 230         Other   India
# 231         Other   India
# 232         Other   India
# 233         Other   India
# 234         Other   India
